# %%
display(dbutils.fs.ls("/FileStore/tables"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/NFA_2018__Asia__2EF_-0cc31.csv</td><td>NFA_2018__Asia__2EF_-0cc31.csv</td><td>553496</td></tr><tr><td>dbfs:/FileStore/tables/apache.log</td><td>apache.log</td><td>4752760</td></tr><tr><td>dbfs:/FileStore/tables/shakespere.txt</td><td>shakespere.txt</td><td>5852404</td></tr></tbody></table></div>

# %%
print dbutils.fs.head("/FileStore/tables/NFA_2018__Asia__2EF_-0cc31.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# ﻿country,ISO alpha-3 code,UN_region,UN_subregion,year,record,crop_land,grazing_land,forest_land,fishing_ground,built_up_land,carbon,total,Percapita GDP (2010 USD),population
# Armenia,ARM,Asia,Western Asia,1992,EFConsPerCap,0.390922543,0.189137286,1.25E-06,0.004137644,0.033668531,1.1122251,1.730092359,949.033,3449000
# Armenia,ARM,Asia,Western Asia,1992,EFConsTotGHA,1348487.313,652429.0666,4.327840599,14272.80369,116139.5982,3836620.482,5967953.592,949.033,3449000
# ...

# %%
textRDD = sc.textFile("dbfs:/FileStore/tables/NFA_2018__Asia__2EF_-0cc31.csv")
plantDF = sqlContext.read.format('com.databricks.spark.csv').options(delimiter=',', header='true', inferschema='true').load("/FileStore/tables/NFA_2018__Asia__2EF_-0cc31.csv")
display(plantDF.take(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
sqlContext.sql("DROP TABLE IF EXISTS plant_dataset")
dbutils.fs.rm("dbfs:/user/hive/warehouse/plant_dataset", True)
sqlContext.registerDataFrameAsTable(plantDF, "plant_dataset")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * FROM plant_dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
desc plant_dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = sqlContext.table("plant_dataset")
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, crop_land as CropLand from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, grazing_land as GrazingLand from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, forest_land as ForestLand from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, fishing_ground as FishingGround from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, built_up_land as BuiltUpLand from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, total as TotalLand from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, `Percapita GDP (2010 USD)` as PercapitaGDP_2010USD from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select carbon as CarbonFootPrint, population as Population from plant_dataset Where record='EFConsTotGHA'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.ml.feature import VectorAssembler

datasetDF = sqlContext.sql("SELECT * FROM plant_dataset WHERE record='EFConsTotGHA'")

vectorizer = VectorAssembler()
#vectorizer.setInputCols(["year", "crop_land", "grazing_land", "forest_land", "fishing_ground", "built_up_land", "total", "Percapita GDP (2010 USD)", "population"])
vectorizer.setInputCols(["year", "total", "Percapita GDP (2010 USD)", "population"])
vectorizer.setOutputCol("features")

datasetDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">112</span><span class="ansired">]: </span>1968
# </div>

# %%
#(split15DF, split85DF) = datasetDF.randomSplit([.15, .85], 1900009193L)
#testSetDF = split15DF.cache()
#trainingSetDF = split85DF.cache()
datasetDF_notNull = datasetDF.filter(datasetDF['carbon'].isNotNull())
#datasetDF_notNull.show()
datasetDF_notNull = datasetDF_notNull.filter(datasetDF_notNull["Percapita GDP (2010 USD)"].isNotNull())
datasetDF_notNull = datasetDF_notNull.filter(datasetDF_notNull["population"].isNotNull())
datasetDF_notNull = datasetDF_notNull.filter(datasetDF_notNull["total"].isNotNull())

testSetDF = datasetDF_notNull.filter(datasetDF_notNull['year']<2011)
trainingSetDF = datasetDF_notNull.filter(datasetDF_notNull['year']>=2011)
print(testSetDF.count())
print(trainingSetDF.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1173
# 144
# </div>

# %%
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml import Pipeline

# Create a DecisionTreeRegressor
dt = DecisionTreeRegressor()

dt.setPredictionCol("Prediction_carbon").setFeaturesCol("features").setLabelCol("carbon").setMaxBins(10000)

# Create a Pipeline
dtPipeline = Pipeline()

# Set the stages of the Pipeline
dtPipeline.setStages([vectorizer, dt])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">114</span><span class="ansired">]: </span>Pipeline_48ff8dd70a51ba671937
# </div>

# %%
# TODO: Replace <FILL_IN> with the appropriate code.
# Let's just reuse our CrossValidator with the new dtPipeline, RegressionEvaluator regEval, and 3 fold cross validation
regEval = RegressionEvaluator(predictionCol="Prediction_carbon", labelCol="carbon", metricName="rmse")
crossval = CrossValidator(estimator=dtPipeline, evaluator=regEval, numFolds=3)

# Let's tune over our dt.maxDepth parameter on the values 2 and 3, create a paramter grid using the ParamGridBuilder
paramGrid = ParamGridBuilder().addGrid(dt.maxDepth, [2, 3]).build()
# Add the grid to the CrossValidator
crossval.setEstimatorParamMaps(paramGrid)

# Now let's find and return the best model
dtModel = crossval.fit(trainingSetDF).bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO: Replace <FILL_IN> with the appropriate code.

# Now let's use dtModel to compute an evaluation metric for our test dataset: testSetDF
resultsDF = dtModel.transform(testSetDF)

# Run the previously created RMSE evaluator, regEval, on the resultsDF DataFrame
rmseDT = regEval.evaluate(resultsDF)

# Now let's compute the r2 evaluation metric for our test dataset
r2DT = regEval.evaluate(resultsDF, {regEval.metricName: 'r2'})

print("DT Root Mean Squared Error: {0:.2f}".format(rmseDT))
print("DT r2: {0:.2f}".format(r2DT))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DT Root Mean Squared Error: 137143095.64
# DT r2: 0.73
# </div>

# %%
print dtModel.stages[-1]._java_obj.toDebugString()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DecisionTreeRegressionModel (uid=DecisionTreeRegressor_435b92dea01449ebc55d) of depth 3 with 15 nodes
#   If (feature 1 &lt;= 3.197697405E9)
#    If (feature 1 &lt;= 5.0536520445000005E8)
#     If (feature 1 &lt;= 1.6351095814999998E8)
#      Predict: 2.501924129539473E7
#     Else (feature 1 &gt; 1.6351095814999998E8)
#      Predict: 1.5226406540444455E8
#    Else (feature 1 &gt; 5.0536520445000005E8)
#     If (feature 2 &lt;= 1695.635)
#      Predict: 6.943179629E8
#     Else (feature 2 &gt; 1695.635)
#      Predict: 4.5330274615E8
#   Else (feature 1 &gt; 3.197697405E9)
#    If (feature 0 &lt;= 2012.5)
# ...
